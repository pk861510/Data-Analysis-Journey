# %%
import pandas as pd

# %%
# Read and load the Survey Result data for analysis
df = pd.read_csv("D:\\Data Analytics\\Data\\survey_results_public.csv")
schema_df = pd.read_csv(r"D:\\Data Analytics\\Data\\survey_results_schema.csv")

# %%
pd.set_option('display.max_columns',139)
df.set_index('ResponseId',inplace = True)

# %%
df.head(1)
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
#
#                                                     EdLevel Employment  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
#
#                                      AILearnHow  YearsCode            DevType  \
# ResponseId
# ...

# %%
# Make a filter for country = 
filt = df["Country"]=="India"

# %%
# fetch all the record of India 
df.loc[filt].head(5)
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 14          I am a developer by profession  25-34 years old
# 16          I am a developer by profession  18-24 years old
# 47          I am a developer by profession  35-44 years old
# 91          I am a developer by profession  25-34 years old
# 134         I am a developer by profession  25-34 years old
#
#                                                  EdLevel Employment  \
# ResponseId
# 14          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Student
# 47          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 91          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 134         Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 14            Caring for dependents (children, elderly, etc.)      6.0
# ...

# %%
# Choosen Column Fetch 
df.loc[filt,["Country","Age","EdLevel"]].head(4)
# Out:
#            Country              Age  \
# ResponseId
# 14           India  25-34 years old
# 16           India  18-24 years old
# 47           India  35-44 years old
# 91           India  25-34 years old
#
#                                                  EdLevel
# ResponseId
# 14          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 47          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 91          Bachelor’s degree (B.A., B.S., B.Eng., etc.)

# %%
# Opposite to our filter by using "~"
df.loc[~filt,["Country","Age","EdLevel"]].head(4)
# Out:
#                 Country              Age  \
# ResponseId
# 1               Ukraine  25-34 years old
# 2           Netherlands  25-34 years old
# 3               Ukraine  35-44 years old
# 4               Ukraine  35-44 years old
#
#                                                     EdLevel
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
