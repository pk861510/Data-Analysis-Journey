# %%
import pandas as pd
from pathlib import Path

# %%
data = pd.read_csv("python_scripts/cleaned_zomato_data.csv")
pd.set_option("display.max_columns",21)

# %%
data.head(1)
# Out:
#    Restaurant ID Restaurant Name  Country Code     City  \
# 0        7402935            Skye            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
#
#                         Locality                        Locality Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
#
#     Longitude  Latitude              Cuisines  Average Cost for two  \
# 0  106.821999 -6.196778  Italian, Continental                800000
#
#                  Currency Has Table booking Has Online delivery  Price range  \
# 0  Indonesian Rupiah(IDR)                No                  No            3
#
#    Aggregate rating Rating color Rating text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia

# %%
# cuisinesDim = data[["Restaurant ID","Cuisines"]]
# cuisinesDim.head()

# %%
# cuisinesDim["Cuisines"] = cuisinesDim["Cuisines"].str.split(",")
# cuisinesDim

# %%
# cuisinesDim = cuisinesDim.explode('Cuisines')
# cuisinesDim.head(5)

# %%
cuisinesDim['Cuisines'] = cuisinesDim['Cuisines'].str.strip()
cuisinesDim.head()
# Out:
#    Restaurant ID     Cuisines
# 0        7402935      Italian
# 1        7402935  Continental
# 2        7410290        Asian
# 3        7410290   Indonesian
# 4        7410290      Western

# %%
data_dir = Path("Data")
data_dir.mkdir(exist_ok = True)

# %%
file_path = data_dir/"cuisinesDim.csv"
cuisinesDim.to_csv(file_path,index= False)

# %%
data.head(1)
# Out:
#    Restaurant ID Restaurant Name  Country Code     City  \
# 0        7402935            Skye            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
#
#                         Locality                        Locality Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
#
#     Longitude  Latitude              Cuisines  Average Cost for two  \
# 0  106.821999 -6.196778  Italian, Continental                800000
#
#                  Currency Has Table booking Has Online delivery  Price range  \
# 0  Indonesian Rupiah(IDR)                No                  No            3
#
#    Aggregate rating Rating color Rating text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia
